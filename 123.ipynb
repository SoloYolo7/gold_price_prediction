# %%
# --- 1. ИМПОРТЫ ---
import os
import warnings
import time
import traceback  # <- ИСПРАВЛЕНО: Добавлен импорт
import tempfile   # <- ИСПРАВЛЕНО: Добавлен импорт

from dotenv import load_dotenv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline

from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from xgboost import XGBRegressor

import optuna
import mlflow
import mlflow.sklearn
from mlflow.models import infer_signature

# --- 2. НАСТРОЙКИ ---
warnings.filterwarnings('ignore')
load_dotenv()
plt.switch_backend("Agg")

# --- 3. НАСТРОЙКИ MLFLOW ---
MLFLOW_TRACKING_URI = os.getenv("MLFLOW_TRACKING_URI", "http://84.201.144.227:8000")
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)
EXPERIMENT_NAME = "financial_timeseries_regression"
mlflow.set_experiment(EXPERIMENT_NAME)
print(f"MLflow URI: {mlflow.get_tracking_uri()}")
print(f"Experiment: {EXPERIMENT_NAME}")

# --- 4. ЗАГРУЗКА ДАННЫХ ---
df = pd.read_csv("data/financial_regression.csv")
df["date"] = pd.to_datetime(df["date"])
df = df.set_index("date")
df.dropna(subset=["gold close"], inplace=True)
df["year"] = df.index.year; df["month"] = df.index.month
y = df["gold close"]
X = df.drop(columns=["gold close"])
split_idx = int(len(X) * 0.8)
X_train_raw, X_test_raw = X.iloc[:split_idx], X.iloc[split_idx:]
y_train, y_test = y.iloc[:split_idx], y.iloc[split_idx:]
feature_names = X_train_raw.columns.tolist()

# --- 5. ВСПОМОГАТЕЛЬНЫЕ ФУНКЦИИ (без изменений) ---
def calc_metrics(y_true, y_pred):
    return {"mae": mean_absolute_error(y_true, y_pred), "r2": r2_score(y_true, y_pred)}

def log_feature_importances(pipeline, model_name, names):
    model = pipeline.named_steps.get("model")
    if hasattr(model, "feature_importances_"):
        importances = model.feature_importances_
        fi = pd.DataFrame({"feature": names, "importance": importances}).sort_values("importance", ascending=False).head(20)
        fig, ax = plt.subplots(figsize=(10, 8))
        ax.barh(fi["feature"], fi["importance"])
        ax.invert_yaxis()
        ax.set_title(f"Feature Importances — {model_name}")
        plt.tight_layout()
        mlflow.log_figure(fig, f"feature_importances_{model_name}.png")
        plt.close(fig)

# --- 6. ФУНКЦИИ OPTUNA (без изменений) ---
def tune_model(trial, model_class, is_catboost=False):
    if is_catboost:
        params = {"iterations": trial.suggest_int("iterations", 100, 200), "depth": trial.suggest_int("depth", 4, 8)}
    else:
        params = {"n_estimators": trial.suggest_int("n_estimators", 100, 200), "max_depth": trial.suggest_int("max_depth", 4, 8)}
    return model_class(random_state=42, **params)

def objective(trial, model_class, is_catboost=False):
    model = tune_model(trial, model_class, is_catboost)
    pipe = Pipeline([("imputer", SimpleImputer(strategy="mean")), ("model", model)])
    # Упрощенная валидация для скорости
    pipe.fit(X_train_raw, y_train)
    pred = pipe.predict(X_test_raw)
    return mean_absolute_error(y_test, pred)

# --- 7. ГЛАВНАЯ ФУНКЦИЯ ЗАПУСКА (ИСПРАВЛЕННАЯ И УПРОЩЕННАЯ) ---
def final_run(model_name, pipeline):
    with mlflow.start_run(run_name=f"{model_name}_Final"):
        # Обучение и оценка
        pipeline.fit(X_train_raw, y_train)
        y_pred = pipeline.predict(X_test_raw)
        metrics = calc_metrics(y_test, y_pred)
        mlflow.log_metrics(metrics)
        log_feature_importances(pipeline, model_name, feature_names)

        # Логирование модели (простой и надежный способ)
        try:
            input_example = X_train_raw.head(5)
            mlflow.sklearn.log_model(
                sk_model=pipeline,
                artifact_path="model_pipeline", # <- ИСПРАВЛЕНО: Возвращен artifact_path
                input_example=input_example
            )
            print(f"✅ УСПЕХ: Модель {model_name} успешно залогирована!")
        except Exception:
            err_txt = "[log_model] failed:\n" + traceback.format_exc()
            print(err_txt)
            # Если основной способ не сработал, пробуем сохранить вручную
            print("Основной метод логирования не удался. Пробуем запасной вариант...")
            try:
                with tempfile.TemporaryDirectory() as tmpdir:
                    local_dir = os.path.join(tmpdir, "model_pipeline")
                    mlflow.sklearn.save_model(sk_model=pipeline, path=local_dir)
                    mlflow.log_artifacts(local_dir, artifact_path="model_pipeline")
                print(f"✅ УСПЕХ: Модель {model_name} успешно залогирована (запасной вариант)!")
            except Exception:
                err_txt = "[save_model/log_artifacts] fallback failed:\n" + traceback.format_exc()
                print(err_txt)
                print(f"❌ ОШИБКА: Не удалось залогировать модель {model_name}.")

# --- 8. ЗАПУСК ЭКСПЕРИМЕНТОВ ---
# CatBoost
print("\n--- CatBoost ---")
study_cat = optuna.create_study(direction="minimize")
study_cat.optimize(lambda trial: objective(trial, CatBoostRegressor, is_catboost=True), n_trials=2)
best_cat_model = tune_model(study_cat.best_trial, CatBoostRegressor, is_catboost=True)
cat_pipe = Pipeline([("imputer", SimpleImputer(strategy="mean")), ("model", best_cat_model)])
final_run("CatBoost_Optuna", cat_pipe)

# XGBoost
print("\n--- XGBoost ---")
study_xgb = optuna.create_study(direction="minimize")
study_xgb.optimize(lambda trial: objective(trial, XGBRegressor), n_trials=2)
best_xgb_model = tune_model(study_xgb.best_trial, XGBRegressor)
xgb_pipe = Pipeline([("imputer", SimpleImputer(strategy="mean")), ("model", best_xgb_model)])
final_run("XGBoost_Optuna", xgb_pipe)

# LightGBM
print("\n--- LightGBM ---")
study_lgbm = optuna.create_study(direction="minimize")
study_lgbm.optimize(lambda trial: objective(trial, LGBMRegressor), n_trials=2)
best_lgbm_model = tune_model(study_lgbm.best_trial, LGBMRegressor)
lgbm_pipe = Pipeline([("imputer", SimpleImputer(strategy="mean")), ("model", best_lgbm_model)])
final_run("LightGBM_Optuna", lgbm_pipe)

print("\n=== All done ===")
# Out:
# [I 2025-09-01 19:57:35,726] A new study created in memory with name: no-name-bfb0b4e5-7946-436a-af35-823bb4969852
# MLflow URI: http://84.201.144.227:8000
# Experiment: financial_timeseries_regression
#
# --- CatBoost ---
# Learning rate set to 0.260374
# 0:	learn: 16.6287491	total: 139ms	remaining: 17.5s
# 1:	learn: 12.9823087	total: 142ms	remaining: 8.86s
# 2:	learn: 9.9834582	total: 144ms	remaining: 5.96s
# 3:	learn: 7.7232313	total: 147ms	remaining: 4.52s
# 4:	learn: 6.0556978	total: 150ms	remaining: 3.65s
# 5:	learn: 4.8299174	total: 153ms	remaining: 3.08s
# 6:	learn: 3.8485984	total: 155ms	remaining: 2.66s
# 7:	learn: 3.1415805	total: 158ms	remaining: 2.35s
# 8:	learn: 2.6121371	total: 161ms	remaining: 2.11s
# 9:	learn: 2.2704514	total: 164ms	remaining: 1.92s
# 10:	learn: 2.0118315	total: 167ms	remaining: 1.76s
# 11:	learn: 1.8360043	total: 169ms	remaining: 1.62s
# 12:	learn: 1.6970575	total: 172ms	remaining: 1.51s
# 13:	learn: 1.5992969	total: 175ms	remaining: 1.41s
# 14:	learn: 1.5189580	total: 177ms	remaining: 1.32s
# 15:	learn: 1.4704049	total: 180ms	remaining: 1.25s
# 16:	learn: 1.4361914	total: 183ms	remaining: 1.18s
# 17:	learn: 1.4091572	total: 185ms	remaining: 1.12s
# 18:	learn: 1.3854936	total: 188ms	remaining: 1.07s
# 19:	learn: 1.3674797	total: 190ms	remaining: 1.02s
# 20:	learn: 1.3288604	total: 192ms	remaining: 971ms
# 21:	learn: 1.3149234	total: 195ms	remaining: 933ms
# 22:	learn: 1.2896437	total: 198ms	remaining: 895ms
# 23:	learn: 1.2805296	total: 200ms	remaining: 859ms
# 24:	learn: 1.2708145	total: 203ms	remaining: 826ms
# 25:	learn: 1.2550849	total: 205ms	remaining: 796ms
# 26:	learn: 1.2475853	total: 207ms	remaining: 767ms
# 27:	learn: 1.2345948	total: 210ms	remaining: 743ms
# 28:	learn: 1.2257891	total: 213ms	remaining: 720ms
# 29:	learn: 1.2139865	total: 215ms	remaining: 696ms
# 30:	learn: 1.2028751	total: 218ms	remaining: 674ms
# 31:	learn: 1.1949901	total: 220ms	remaining: 654ms
# 32:	learn: 1.1761606	total: 223ms	remaining: 634ms
# 33:	learn: 1.1640920	total: 225ms	remaining: 616ms
# 34:	learn: 1.1574563	total: 228ms	remaining: 599ms
# 35:	learn: 1.1478373	total: 231ms	remaining: 583ms
# 36:	learn: 1.1253423	total: 233ms	remaining: 567ms
# 37:	learn: 1.1142374	total: 235ms	remaining: 551ms
# 38:	learn: 1.1069660	total: 238ms	remaining: 536ms
# 39:	learn: 1.0846385	total: 240ms	remaining: 522ms
# 40:	learn: 1.0742210	total: 243ms	remaining: 509ms
# 41:	learn: 1.0671905	total: 245ms	remaining: 496ms
# 42:	learn: 1.0431076	total: 248ms	remaining: 484ms
# 43:	learn: 1.0160165	total: 250ms	remaining: 471ms
# 44:	learn: 1.0016941	total: 252ms	remaining: 460ms
# 45:	learn: 0.9939160	total: 255ms	remaining: 449ms
# 46:	learn: 0.9815596	total: 258ms	remaining: 439ms
# 47:	learn: 0.9728160	total: 260ms	remaining: 428ms
# 48:	learn: 0.9575677	total: 263ms	remaining: 418ms
# 49:	learn: 0.9478814	total: 265ms	remaining: 408ms
# 50:	learn: 0.9387781	total: 267ms	remaining: 398ms
# 51:	learn: 0.9260038	total: 270ms	remaining: 389ms
# 52:	learn: 0.9225008	total: 272ms	remaining: 380ms
# 53:	learn: 0.9160843	total: 275ms	remaining: 371ms
# 54:	learn: 0.9090138	total: 277ms	remaining: 363ms
# 55:	learn: 0.8960643	total: 280ms	remaining: 355ms
# 56:	learn: 0.8880788	total: 282ms	remaining: 346ms
# 57:	learn: 0.8826084	total: 285ms	remaining: 338ms
# 58:	learn: 0.8785421	total: 287ms	remaining: 331ms
# 59:	learn: 0.8733927	total: 290ms	remaining: 324ms
# 60:	learn: 0.8709694	total: 292ms	remaining: 316ms
# 61:	learn: 0.8619020	total: 295ms	remaining: 309ms
# 62:	learn: 0.8545690	total: 297ms	remaining: 302ms
# 63:	learn: 0.8409037	total: 299ms	remaining: 295ms
# 64:	learn: 0.8328481	total: 302ms	remaining: 288ms
# 65:	learn: 0.8233116	total: 304ms	remaining: 281ms
# 66:	learn: 0.8126526	total: 307ms	remaining: 275ms
# 67:	learn: 0.8115367	total: 309ms	remaining: 268ms
# 68:	learn: 0.8078656	total: 312ms	remaining: 262ms
# 69:	learn: 0.8014083	total: 314ms	remaining: 256ms
# 70:	learn: 0.7963148	total: 317ms	remaining: 250ms
# 71:	learn: 0.7926275	total: 319ms	remaining: 244ms
# 72:	learn: 0.7910372	total: 322ms	remaining: 238ms
# 73:	learn: 0.7858091	total: 324ms	remaining: 232ms
# 74:	learn: 0.7852883	total: 327ms	remaining: 227ms
# 75:	learn: 0.7816935	total: 330ms	remaining: 221ms
# 76:	learn: 0.7792769	total: 332ms	remaining: 216ms
# 77:	learn: 0.7778267	total: 334ms	remaining: 210ms
# 78:	learn: 0.7731158	total: 337ms	remaining: 205ms
# [I 2025-09-01 19:57:36,286] Trial 0 finished with value: 11.1105036472402 and parameters: {'iterations': 127, 'depth': 5}. Best is trial 0 with value: 11.1105036472402.
# 79:	learn: 0.7624193	total: 340ms	remaining: 200ms
# 80:	learn: 0.7598253	total: 343ms	remaining: 195ms
# 81:	learn: 0.7571643	total: 345ms	remaining: 189ms
# 82:	learn: 0.7477602	total: 348ms	remaining: 184ms
# 83:	learn: 0.7447679	total: 350ms	remaining: 179ms
# 84:	learn: 0.7417858	total: 353ms	remaining: 174ms
# 85:	learn: 0.7341638	total: 356ms	remaining: 170ms
# 86:	learn: 0.7288152	total: 358ms	remaining: 165ms
# 87:	learn: 0.7259045	total: 361ms	remaining: 160ms
# 88:	learn: 0.7203325	total: 363ms	remaining: 155ms
# 89:	learn: 0.7180922	total: 366ms	remaining: 150ms
# 90:	learn: 0.7147420	total: 369ms	remaining: 146ms
# 91:	learn: 0.7075832	total: 372ms	remaining: 141ms
# 92:	learn: 0.7008001	total: 374ms	remaining: 137ms
# 93:	learn: 0.6986582	total: 376ms	remaining: 132ms
# 94:	learn: 0.6955708	total: 379ms	remaining: 128ms
# 95:	learn: 0.6950713	total: 381ms	remaining: 123ms
# 96:	learn: 0.6917724	total: 384ms	remaining: 119ms
# 97:	learn: 0.6860198	total: 387ms	remaining: 114ms
# 98:	learn: 0.6832623	total: 390ms	remaining: 110ms
# 99:	learn: 0.6756232	total: 392ms	remaining: 106ms
# 100:	learn: 0.6713563	total: 394ms	remaining: 101ms
# 101:	learn: 0.6674791	total: 396ms	remaining: 97.2ms
# 102:	learn: 0.6671805	total: 399ms	remaining: 93.1ms
# 103:	learn: 0.6635900	total: 402ms	remaining: 88.9ms
# 104:	learn: 0.6609196	total: 404ms	remaining: 84.7ms
# 105:	learn: 0.6575877	total: 407ms	remaining: 80.6ms
# 106:	learn: 0.6540452	total: 409ms	remaining: 76.5ms
# 107:	learn: 0.6503603	total: 411ms	remaining: 72.4ms
# 108:	learn: 0.6474540	total: 414ms	remaining: 68.4ms
# 109:	learn: 0.6448787	total: 417ms	remaining: 64.4ms
# 110:	learn: 0.6441023	total: 419ms	remaining: 60.4ms
# 111:	learn: 0.6436992	total: 421ms	remaining: 56.4ms
# 112:	learn: 0.6387187	total: 424ms	remaining: 52.5ms
# 113:	learn: 0.6362795	total: 426ms	remaining: 48.6ms
# 114:	learn: 0.6347892	total: 428ms	remaining: 44.7ms
# 115:	learn: 0.6325812	total: 431ms	remaining: 40.9ms
# 116:	learn: 0.6322232	total: 434ms	remaining: 37.1ms
# 117:	learn: 0.6290182	total: 436ms	remaining: 33.2ms
# 118:	learn: 0.6267343	total: 438ms	remaining: 29.5ms
# 119:	learn: 0.6239480	total: 441ms	remaining: 25.7ms
# 120:	learn: 0.6234779	total: 443ms	remaining: 22ms
# 121:	learn: 0.6214083	total: 446ms	remaining: 18.3ms
# 122:	learn: 0.6178927	total: 448ms	remaining: 14.6ms
# 123:	learn: 0.6134995	total: 451ms	remaining: 10.9ms
# 124:	learn: 0.6113702	total: 453ms	remaining: 7.25ms
# 125:	learn: 0.6084173	total: 456ms	remaining: 3.62ms
# 126:	learn: 0.6060820	total: 458ms	remaining: 0us
# Learning rate set to 0.246277
# 0:	learn: 17.0472393	total: 2.29ms	remaining: 309ms
# 1:	learn: 13.2956319	total: 4.24ms	remaining: 284ms
# 2:	learn: 10.4394657	total: 6.11ms	remaining: 271ms
# 3:	learn: 8.2235610	total: 7.99ms	remaining: 264ms
# 4:	learn: 6.4586194	total: 9.89ms	remaining: 259ms
# 5:	learn: 5.1969000	total: 11.6ms	remaining: 250ms
# 6:	learn: 4.2406133	total: 13.2ms	remaining: 243ms
# 7:	learn: 3.4664338	total: 14.8ms	remaining: 238ms
# 8:	learn: 2.8974042	total: 16.8ms	remaining: 236ms
# 9:	learn: 2.4645903	total: 18.5ms	remaining: 234ms
# 10:	learn: 2.1572150	total: 20.3ms	remaining: 231ms
# 11:	learn: 1.9383076	total: 21.9ms	remaining: 227ms
# 12:	learn: 1.7751297	total: 24.3ms	remaining: 230ms
# 13:	learn: 1.6684697	total: 26.2ms	remaining: 228ms
# 14:	learn: 1.5889017	total: 27.8ms	remaining: 224ms
# 15:	learn: 1.5242158	total: 29.4ms	remaining: 221ms
# 16:	learn: 1.4755321	total: 31ms	remaining: 217ms
# 17:	learn: 1.4224395	total: 33ms	remaining: 216ms
# 18:	learn: 1.3925125	total: 34.7ms	remaining: 213ms
# 19:	learn: 1.3730823	total: 36.4ms	remaining: 211ms
# 20:	learn: 1.3521041	total: 38.1ms	remaining: 209ms
# 21:	learn: 1.3333949	total: 39.8ms	remaining: 206ms
# 22:	learn: 1.3177169	total: 41.7ms	remaining: 205ms
# 23:	learn: 1.2721320	total: 43.6ms	remaining: 203ms
# 24:	learn: 1.2602496	total: 45.5ms	remaining: 202ms
# 25:	learn: 1.2478837	total: 47.4ms	remaining: 201ms
# 26:	learn: 1.2336216	total: 49.5ms	remaining: 200ms
# 27:	learn: 1.2194850	total: 51.3ms	remaining: 198ms
# 28:	learn: 1.2116967	total: 53.3ms	remaining: 197ms
# 29:	learn: 1.1945035	total: 55.1ms	remaining: 195ms
# 30:	learn: 1.1765576	total: 56.9ms	remaining: 193ms
# 31:	learn: 1.1668141	total: 58.5ms	remaining: 190ms
# 32:	learn: 1.1539454	total: 60.2ms	remaining: 188ms
# 33:	learn: 1.1351033	total: 61.8ms	remaining: 185ms
# 34:	learn: 1.1262877	total: 63.5ms	remaining: 183ms
# 35:	learn: 1.1112925	total: 65.3ms	remaining: 181ms
# 36:	learn: 1.1057455	total: 67.3ms	remaining: 180ms
# 37:	learn: 1.0879821	total: 69ms	remaining: 178ms
# 38:	learn: 1.0611321	total: 70.7ms	remaining: 176ms
# 39:	learn: 1.0532017	total: 72.4ms	remaining: 174ms
# 40:	learn: 1.0393378	total: 74.1ms	remaining: 172ms
# 41:	learn: 1.0325507	total: 75.8ms	remaining: 170ms
# 42:	learn: 1.0249445	total: 77.5ms	remaining: 168ms
# 43:	learn: 1.0150896	total: 79.4ms	remaining: 166ms
# 44:	learn: 1.0101688	total: 81.5ms	remaining: 165ms
# 45:	learn: 1.0057568	total: 83.3ms	remaining: 163ms
# 46:	learn: 0.9907070	total: 84.9ms	remaining: 161ms
# 47:	learn: 0.9822407	total: 86.6ms	remaining: 159ms
# 48:	learn: 0.9613637	total: 88.3ms	remaining: 157ms
# 49:	learn: 0.9571845	total: 90ms	remaining: 155ms
# 50:	learn: 0.9539084	total: 91.6ms	remaining: 153ms
# 51:	learn: 0.9487671	total: 93.2ms	remaining: 151ms
# 52:	learn: 0.9392908	total: 94.9ms	remaining: 149ms
# 53:	learn: 0.9366202	total: 97ms	remaining: 147ms
# 54:	learn: 0.9253647	total: 98.8ms	remaining: 146ms
# 55:	learn: 0.9181661	total: 100ms	remaining: 143ms
# 56:	learn: 0.9032693	total: 102ms	remaining: 142ms
# 57:	learn: 0.8947816	total: 104ms	remaining: 140ms
# 58:	learn: 0.8921558	total: 105ms	remaining: 138ms
# 59:	learn: 0.8897379	total: 107ms	remaining: 136ms
# 60:	learn: 0.8861012	total: 109ms	remaining: 134ms
# 61:	learn: 0.8799302	total: 110ms	remaining: 132ms
# 62:	learn: 0.8696199	total: 112ms	remaining: 130ms
# 63:	learn: 0.8662149	total: 114ms	remaining: 128ms
# 64:	learn: 0.8627158	total: 116ms	remaining: 127ms
# 65:	learn: 0.8583893	total: 118ms	remaining: 125ms
# 66:	learn: 0.8555289	total: 119ms	remaining: 123ms
# 67:	learn: 0.8517723	total: 121ms	remaining: 121ms
# 68:	learn: 0.8486180	total: 123ms	remaining: 119ms
# 69:	learn: 0.8428217	total: 124ms	remaining: 117ms
# 70:	learn: 0.8362437	total: 126ms	remaining: 115ms
# 71:	learn: 0.8216121	total: 128ms	remaining: 114ms
# 72:	learn: 0.8199469	total: 130ms	remaining: 112ms
# 73:	learn: 0.8142582	total: 132ms	remaining: 110ms
# 74:	learn: 0.8058124	total: 133ms	remaining: 109ms
# 75:	learn: 0.7999396	total: 135ms	remaining: 107ms
# 76:	learn: 0.7916415	total: 137ms	remaining: 105ms
# 77:	learn: 0.7888440	total: 138ms	remaining: 103ms
# 78:	learn: 0.7802711	total: 141ms	remaining: 101ms
# 79:	learn: 0.7782399	total: 142ms	remaining: 99.6ms
# 80:	learn: 0.7750727	total: 144ms	remaining: 97.8ms
# 81:	learn: 0.7694465	total: 146ms	remaining: 96ms
# 82:	learn: 0.7663843	total: 148ms	remaining: 94.3ms
# 83:	learn: 0.7641937	total: 149ms	remaining: 92.4ms
# 84:	learn: 0.7595559	total: 151ms	remaining: 90.6ms
# 85:	learn: 0.7542666	total: 153ms	remaining: 88.8ms
# 86:	learn: 0.7511463	total: 155ms	remaining: 87ms
# 87:	learn: 0.7482115	total: 156ms	remaining: 85.2ms
# 88:	learn: 0.7390345	total: 158ms	remaining: 83.4ms
# 89:	learn: 0.7386544	total: 160ms	remaining: 81.6ms
# 90:	learn: 0.7332968	total: 161ms	remaining: 79.8ms
# 91:	learn: 0.7294182	total: 163ms	remaining: 78ms
# 92:	learn: 0.7269416	total: 165ms	remaining: 76.2ms
# 93:	learn: 0.7252711	total: 166ms	remaining: 74.3ms
# 94:	learn: 0.7223507	total: 168ms	remaining: 72.5ms
# 95:	learn: 0.7192652	total: 170ms	remaining: 70.7ms
# 96:	learn: 0.7166172	total: 171ms	remaining: 68.9ms
# 97:	learn: 0.7146131	total: 173ms	remaining: 67.1ms
# 98:	learn: 0.7117030	total: 175ms	remaining: 65.4ms
# 99:	learn: 0.7074006	total: 177ms	remaining: 63.7ms
# 100:	learn: 0.7048047	total: 179ms	remaining: 61.9ms
# 101:	learn: 0.6990541	total: 180ms	remaining: 60ms
# 102:	learn: 0.6950243	total: 182ms	remaining: 58.2ms
# 103:	learn: 0.6924487	total: 184ms	remaining: 56.5ms
# 104:	learn: 0.6907179	total: 186ms	remaining: 54.8ms
# 105:	learn: 0.6881512	total: 187ms	remaining: 53ms
# 106:	learn: 0.6864334	total: 189ms	remaining: 51.2ms
# 107:	learn: 0.6853222	total: 191ms	remaining: 49.5ms
# 108:	learn: 0.6811256	total: 193ms	remaining: 47.7ms
# 109:	learn: 0.6788375	total: 194ms	remaining: 45.9ms
# 110:	learn: 0.6781307	total: 196ms	remaining: 44.1ms
# 111:	learn: 0.6761010	total: 198ms	remaining: 42.4ms
# 112:	learn: 0.6740760	total: 200ms	remaining: 40.6ms
# 113:	learn: 0.6716453	total: 201ms	remaining: 38.8ms
# 114:	learn: 0.6671870	total: 203ms	remaining: 37ms
# 115:	learn: 0.6646215	total: 204ms	remaining: 35.3ms
# 116:	learn: 0.6605115	total: 206ms	remaining: 33.5ms
# 117:	learn: 0.6589472	total: 208ms	remaining: 31.8ms
# 118:	learn: 0.6557016	total: 210ms	remaining: 30ms
# 119:	learn: 0.6545238	total: 212ms	remaining: 28.2ms
# [I 2025-09-01 19:57:36,607] Trial 1 finished with value: 9.965203573448914 and parameters: {'iterations': 136, 'depth': 4}. Best is trial 1 with value: 9.965203573448914.
# 120:	learn: 0.6533830	total: 214ms	remaining: 26.5ms
# 121:	learn: 0.6509717	total: 216ms	remaining: 24.8ms
# 122:	learn: 0.6491857	total: 218ms	remaining: 23ms
# 123:	learn: 0.6481063	total: 219ms	remaining: 21.2ms
# 124:	learn: 0.6462394	total: 221ms	remaining: 19.5ms
# 125:	learn: 0.6454318	total: 223ms	remaining: 17.7ms
# 126:	learn: 0.6442761	total: 225ms	remaining: 15.9ms
# 127:	learn: 0.6414253	total: 226ms	remaining: 14.1ms
# 128:	learn: 0.6400658	total: 228ms	remaining: 12.4ms
# 129:	learn: 0.6382141	total: 230ms	remaining: 10.6ms
# 130:	learn: 0.6355625	total: 232ms	remaining: 8.84ms
# 131:	learn: 0.6343918	total: 233ms	remaining: 7.07ms
# 132:	learn: 0.6327434	total: 235ms	remaining: 5.3ms
# 133:	learn: 0.6313395	total: 237ms	remaining: 3.53ms
# 134:	learn: 0.6303149	total: 239ms	remaining: 1.77ms
# 135:	learn: 0.6255269	total: 240ms	remaining: 0us
# Learning rate set to 0.246277
# 0:	learn: 17.0472393	total: 2.34ms	remaining: 316ms
# 1:	learn: 13.2956319	total: 4.35ms	remaining: 291ms
# 2:	learn: 10.4394657	total: 6.13ms	remaining: 272ms
# 3:	learn: 8.2235610	total: 8.79ms	remaining: 290ms
# 4:	learn: 6.4586194	total: 11ms	remaining: 287ms
# 5:	learn: 5.1969000	total: 12.9ms	remaining: 280ms
# 6:	learn: 4.2406133	total: 15ms	remaining: 277ms
# 7:	learn: 3.4664338	total: 17ms	remaining: 271ms
# 8:	learn: 2.8974042	total: 18.8ms	remaining: 266ms
# 9:	learn: 2.4645903	total: 20.7ms	remaining: 260ms
# 10:	learn: 2.1572150	total: 22.4ms	remaining: 255ms
# 11:	learn: 1.9383076	total: 24.2ms	remaining: 250ms
# 12:	learn: 1.7751297	total: 26ms	remaining: 246ms
# 13:	learn: 1.6684697	total: 27.7ms	remaining: 242ms
# 14:	learn: 1.5889017	total: 29.5ms	remaining: 238ms
# 15:	learn: 1.5242158	total: 31.6ms	remaining: 237ms
# 16:	learn: 1.4755321	total: 33.4ms	remaining: 234ms
# 17:	learn: 1.4224395	total: 35.2ms	remaining: 231ms
# 18:	learn: 1.3925125	total: 37.4ms	remaining: 230ms
# 19:	learn: 1.3730823	total: 39.6ms	remaining: 230ms
# 20:	learn: 1.3521041	total: 41.7ms	remaining: 229ms
# 21:	learn: 1.3333949	total: 43.7ms	remaining: 227ms
# 22:	learn: 1.3177169	total: 45.6ms	remaining: 224ms
# 23:	learn: 1.2721320	total: 47.6ms	remaining: 222ms
# 24:	learn: 1.2602496	total: 49.5ms	remaining: 220ms
# 25:	learn: 1.2478837	total: 51.4ms	remaining: 217ms
# 26:	learn: 1.2336216	total: 53.2ms	remaining: 215ms
# 27:	learn: 1.2194850	total: 55.2ms	remaining: 213ms
# 28:	learn: 1.2116967	total: 57ms	remaining: 210ms
# 29:	learn: 1.1945035	total: 58.9ms	remaining: 208ms
# 30:	learn: 1.1765576	total: 60.7ms	remaining: 206ms
# 31:	learn: 1.1668141	total: 62.8ms	remaining: 204ms
# 32:	learn: 1.1539454	total: 64.9ms	remaining: 203ms
# 33:	learn: 1.1351033	total: 66.9ms	remaining: 201ms
# 34:	learn: 1.1262877	total: 68.7ms	remaining: 198ms
# 35:	learn: 1.1112925	total: 70.6ms	remaining: 196ms
# 36:	learn: 1.1057455	total: 72.3ms	remaining: 194ms
# 37:	learn: 1.0879821	total: 74.1ms	remaining: 191ms
# 38:	learn: 1.0611321	total: 75.9ms	remaining: 189ms
# 39:	learn: 1.0532017	total: 77.9ms	remaining: 187ms
# 40:	learn: 1.0393378	total: 80.1ms	remaining: 186ms
# 41:	learn: 1.0325507	total: 82ms	remaining: 183ms
# 42:	learn: 1.0249445	total: 83.8ms	remaining: 181ms
# 43:	learn: 1.0150896	total: 85.7ms	remaining: 179ms
# 44:	learn: 1.0101688	total: 87.5ms	remaining: 177ms
# 45:	learn: 1.0057568	total: 89.2ms	remaining: 174ms
# 46:	learn: 0.9907070	total: 90.9ms	remaining: 172ms
# 47:	learn: 0.9822407	total: 92.8ms	remaining: 170ms
# 48:	learn: 0.9613637	total: 94.9ms	remaining: 168ms
# 49:	learn: 0.9571845	total: 96.7ms	remaining: 166ms
# 50:	learn: 0.9539084	total: 98.4ms	remaining: 164ms
# 51:	learn: 0.9487671	total: 100ms	remaining: 162ms
# 52:	learn: 0.9392908	total: 102ms	remaining: 159ms
# 53:	learn: 0.9366202	total: 103ms	remaining: 157ms
# 54:	learn: 0.9253647	total: 105ms	remaining: 155ms
# 55:	learn: 0.9181661	total: 107ms	remaining: 153ms
# 56:	learn: 0.9032693	total: 109ms	remaining: 151ms
# 57:	learn: 0.8947816	total: 111ms	remaining: 149ms
# 58:	learn: 0.8921558	total: 113ms	remaining: 147ms
# 59:	learn: 0.8897379	total: 114ms	remaining: 145ms
# 60:	learn: 0.8861012	total: 116ms	remaining: 142ms
# 61:	learn: 0.8799302	total: 118ms	remaining: 140ms
# 62:	learn: 0.8696199	total: 119ms	remaining: 138ms
# 63:	learn: 0.8662149	total: 121ms	remaining: 136ms
# 64:	learn: 0.8627158	total: 123ms	remaining: 134ms
# 65:	learn: 0.8583893	total: 125ms	remaining: 132ms
# 66:	learn: 0.8555289	total: 127ms	remaining: 130ms
# 67:	learn: 0.8517723	total: 128ms	remaining: 128ms
# 68:	learn: 0.8486180	total: 130ms	remaining: 126ms
# 69:	learn: 0.8428217	total: 132ms	remaining: 124ms
# 70:	learn: 0.8362437	total: 133ms	remaining: 122ms
# 71:	learn: 0.8216121	total: 135ms	remaining: 120ms
# 72:	learn: 0.8199469	total: 137ms	remaining: 118ms
# 73:	learn: 0.8142582	total: 139ms	remaining: 116ms
# 74:	learn: 0.8058124	total: 141ms	remaining: 114ms
# 75:	learn: 0.7999396	total: 142ms	remaining: 112ms
# 76:	learn: 0.7916415	total: 144ms	remaining: 111ms
# 77:	learn: 0.7888440	total: 146ms	remaining: 108ms
# 78:	learn: 0.7802711	total: 148ms	remaining: 107ms
# 79:	learn: 0.7782399	total: 150ms	remaining: 105ms
# 80:	learn: 0.7750727	total: 151ms	remaining: 103ms
# 81:	learn: 0.7694465	total: 153ms	remaining: 101ms
# 82:	learn: 0.7663843	total: 155ms	remaining: 99.1ms
# 83:	learn: 0.7641937	total: 157ms	remaining: 97.3ms
# 84:	learn: 0.7595559	total: 159ms	remaining: 95.4ms
# 85:	learn: 0.7542666	total: 161ms	remaining: 93.5ms
# 86:	learn: 0.7511463	total: 163ms	remaining: 91.6ms
# 87:	learn: 0.7482115	total: 164ms	remaining: 89.7ms
# 88:	learn: 0.7390345	total: 166ms	remaining: 87.8ms
# 89:	learn: 0.7386544	total: 168ms	remaining: 85.8ms
# 90:	learn: 0.7332968	total: 170ms	remaining: 83.8ms
# 91:	learn: 0.7294182	total: 171ms	remaining: 82ms
# 92:	learn: 0.7269416	total: 173ms	remaining: 80.2ms
# 93:	learn: 0.7252711	total: 175ms	remaining: 78.3ms
# 94:	learn: 0.7223507	total: 177ms	remaining: 76.4ms
# 95:	learn: 0.7192652	total: 179ms	remaining: 74.5ms
# 96:	learn: 0.7166172	total: 181ms	remaining: 72.6ms
# 97:	learn: 0.7146131	total: 182ms	remaining: 70.7ms
# 98:	learn: 0.7117030	total: 184ms	remaining: 68.7ms
# 99:	learn: 0.7074006	total: 186ms	remaining: 66.8ms
# 100:	learn: 0.7048047	total: 187ms	remaining: 65ms
# 101:	learn: 0.6990541	total: 189ms	remaining: 63.1ms
# 102:	learn: 0.6950243	total: 192ms	remaining: 61.5ms
# 103:	learn: 0.6924487	total: 194ms	remaining: 59.8ms
# 104:	learn: 0.6907179	total: 196ms	remaining: 57.9ms
# 105:	learn: 0.6881512	total: 198ms	remaining: 55.9ms
# 106:	learn: 0.6864334	total: 199ms	remaining: 54ms
# 107:	learn: 0.6853222	total: 201ms	remaining: 52.1ms
# 108:	learn: 0.6811256	total: 203ms	remaining: 50.2ms
# 109:	learn: 0.6788375	total: 205ms	remaining: 48.4ms
# 110:	learn: 0.6781307	total: 206ms	remaining: 46.4ms
# 111:	learn: 0.6761010	total: 208ms	remaining: 44.6ms
# 112:	learn: 0.6740760	total: 210ms	remaining: 42.7ms
# 113:	learn: 0.6716453	total: 212ms	remaining: 40.8ms
# 114:	learn: 0.6671870	total: 213ms	remaining: 39ms
# 115:	learn: 0.6646215	total: 215ms	remaining: 37.1ms
# 116:	learn: 0.6605115	total: 217ms	remaining: 35.2ms
# 117:	learn: 0.6589472	total: 219ms	remaining: 33.4ms
# 118:	learn: 0.6557016	total: 221ms	remaining: 31.5ms
# 119:	learn: 0.6545238	total: 223ms	remaining: 29.7ms
# 120:	learn: 0.6533830	total: 224ms	remaining: 27.8ms
# 121:	learn: 0.6509717	total: 226ms	remaining: 25.9ms
# 122:	learn: 0.6491857	total: 228ms	remaining: 24.1ms
# 123:	learn: 0.6481063	total: 229ms	remaining: 22.2ms
# 124:	learn: 0.6462394	total: 231ms	remaining: 20.3ms
# 125:	learn: 0.6454318	total: 233ms	remaining: 18.5ms
# 126:	learn: 0.6442761	total: 235ms	remaining: 16.6ms
# 127:	learn: 0.6414253	total: 237ms	remaining: 14.8ms
# 128:	learn: 0.6400658	total: 238ms	remaining: 12.9ms
# 129:	learn: 0.6382141	total: 240ms	remaining: 11.1ms
# 130:	learn: 0.6355625	total: 242ms	remaining: 9.22ms
# 131:	learn: 0.6343918	total: 243ms	remaining: 7.38ms
# 132:	learn: 0.6327434	total: 245ms	remaining: 5.53ms
# 133:	learn: 0.6313395	total: 247ms	remaining: 3.68ms
# 134:	learn: 0.6303149	total: 248ms	remaining: 1.84ms
# 135:	learn: 0.6255269	total: 250ms	remaining: 0us
# Downloading artifacts:   0%|          | 0/7 [00:00<?, ?it/s]
# [I 2025-09-01 19:57:46,469] A new study created in memory with name: no-name-d99e178a-bda7-455e-993b-988ea8b0a849
# ✅ УСПЕХ: Модель CatBoost_Optuna успешно залогирована!
# 🏃 View run CatBoost_Optuna_Final at: http://84.201.144.227:8000/#/experiments/8/runs/50e2caf79c1445799ce66069d856534b
# 🧪 View experiment at: http://84.201.144.227:8000/#/experiments/8
#
# --- XGBoost ---
# [I 2025-09-01 19:57:47,302] Trial 0 finished with value: 8.965506393268544 and parameters: {'n_estimators': 114, 'max_depth': 8}. Best is trial 0 with value: 8.965506393268544.
# [I 2025-09-01 19:57:48,489] Trial 1 finished with value: 8.965739840435726 and parameters: {'n_estimators': 174, 'max_depth': 8}. Best is trial 0 with value: 8.965506393268544.
# Downloading artifacts:   0%|          | 0/7 [00:00<?, ?it/s]
# [I 2025-09-01 19:57:54,512] A new study created in memory with name: no-name-68eb89f3-5b39-448b-82d8-f0aa09c6d779
# ✅ УСПЕХ: Модель XGBoost_Optuna успешно залогирована!
# 🏃 View run XGBoost_Optuna_Final at: http://84.201.144.227:8000/#/experiments/8/runs/53f38cf31efd4f60bfdecf7dba9bd9f6
# 🧪 View experiment at: http://84.201.144.227:8000/#/experiments/8
#
# --- LightGBM ---
# [I 2025-09-01 19:57:56,278] Trial 0 finished with value: 8.927154074239581 and parameters: {'n_estimators': 107, 'max_depth': 6}. Best is trial 0 with value: 8.927154074239581.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001321 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 10792
# [LightGBM] [Info] Number of data points in the train set: 2975, number of used features: 46
# [LightGBM] [Info] Start training from score 135.491479
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001164 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 10792
# [LightGBM] [Info] Number of data points in the train set: 2975, number of used features: 46
# [LightGBM] [Info] Start training from score 135.491479
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [I 2025-09-01 19:57:56,423] Trial 1 finished with value: 8.935278759186843 and parameters: {'n_estimators': 145, 'max_depth': 6}. Best is trial 0 with value: 8.927154074239581.
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001065 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 10792
# [LightGBM] [Info] Number of data points in the train set: 2975, number of used features: 46
# [LightGBM] [Info] Start training from score 135.491479
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Downloading artifacts:   0%|          | 0/7 [00:00<?, ?it/s]
# ✅ УСПЕХ: Модель LightGBM_Optuna успешно залогирована!
# 🏃 View run LightGBM_Optuna_Final at: http://84.201.144.227:8000/#/experiments/8/runs/620920d8be23464388fed13ac00fb88b
# 🧪 View experiment at: http://84.201.144.227:8000/#/experiments/8
#
# === All done ===
